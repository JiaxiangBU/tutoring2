# %%
import pandas as pd
# %matplotlib inline
import matplotlib
matplotlib.rcParams['figure.figsize'] = [20,10]

# %%
pd.Series([1,2,3,4,5,6]).plot()

# %%
matplotlib.rcParams['figure.figsize'] = [2,1]

# %%
pd.Series([1,2,3,4,5,6]).plot()
